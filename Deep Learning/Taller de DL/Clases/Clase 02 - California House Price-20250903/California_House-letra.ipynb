# %% [markdown]
# # California Housing Prices: Regresión con PyTorch y Weights & Biases
#
# En esta notebook, implementaremos un modelo de regresión para predecir valores medianos de casas basado en un conjunto de datos de características demográficas y geográficas. Además, presentaremos los aspectos básicos del entrenamiento de modelos en PyTorch y utilizaremos la herramienta Weights & Biases (W&B) para el seguimiento y visualización de los experimentos.
#
# ## Introduction
#
# ### Objetivos
#
# 1. **Implementar un modelo de regresión** utilizando PyTorch.
# 2. **Configurar y utilizar W&B** para el seguimiento de métricas y visualización de resultados.
#
# ### Contenido
#
# 1. Configuración de bibliotecas y semillas para reproducibilidad.
# 2. Carga y exploración del dataset `housing.csv`.
# 3. Preparación de datos y división en conjuntos de entrenamiento y prueba.
# 4. Definición y entrenamiento de un modelo de regresión en PyTorch.
# 5. Integración de W&B para el seguimiento de experimentos y visualización de métricas.
#
# ### Sobre el conjunto de datos
#
# Los datos se refieren a las casas que se encuentran en un determinado distrito de California y algunas estadísticas resumidas sobre ellas basadas en los datos del censo de 1990. Hay que tener en cuenta que los datos no están depurados, por lo que se requieren algunos pasos de preprocesamiento. El objetivo es predecir el valor medio de las casas para los distritos de California, por lo que se trata de un problema de regresión.

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split

from torchinfo import summary

from sklearn.datasets import fetch_california_housing
import matplotlib.pyplot as plt

# %%
# Fijamos la semilla para que los resultados sean reproducibles
SEED = 34

torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
import sys

# definimos el dispositivo que vamos a usar
DEVICE = "cpu"  # por defecto, usamos la CPU
if torch.cuda.is_available():
    DEVICE = "cuda"  # si hay GPU, usamos la GPU
elif torch.backends.mps.is_available():
    DEVICE = "mps"  # si no hay GPU, pero hay MPS, usamos MPS
elif torch.backends.xpu.is_available():
    DEVICE = "xpu"  # si no hay GPU, pero hay XPU, usamos XPU

print(f"Usando {DEVICE}")

NUM_WORKERS = 0 # Win y MacOS pueden tener problemas con múltiples workers
if sys.platform == 'linux':
    NUM_WORKERS = 4  # numero de workers para cargar los datos (depende de cada caso)

print(f"Usando {NUM_WORKERS}")
# Out:
# Usando mps
# Usando 0

# %%
BATCH_SIZE = 1024  # tamaño del batch

# %% [markdown]
# ## Carga de datos + Exploración

# %%
california_housing = fetch_california_housing(as_frame=True)
target_column_name = california_housing.target_names[0]  # 'MedHouseVal'
print(california_housing.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# A household is a group of people residing within a home. Since the average
# number of rooms and bedrooms in this dataset are provided per household, these
# columns may take surprisingly large values for block groups with few households
# and many empty houses, such as vacation resorts.
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. rubric:: References
#
# - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#   Statistics and Probability Letters, 33:291-297, 1997.

# %%
df = california_housing.frame  # Convertimos el dataset en un DataFrame de pandas
df.head()  # Mostramos las primeras filas del DataFrame
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
df.describe()  # Mostramos un resumen de las estadísticas del DataFrame
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# min        0.692308     32.540000   -124.350000      0.149990
# 25%        2.429741     33.930000   -121.800000      1.196000
# 50%        2.818116     34.260000   -118.490000      1.797000
# 75%        3.282261     37.710000   -118.010000      2.647250
# max     1243.333333     41.950000   -114.310000      5.000010

# %%
# Chequear si hay valores nulos
df.isnull().sum()
# Out:
# MedInc         0
# HouseAge       0
# AveRooms       0
# AveBedrms      0
# Population     0
# AveOccup       0
# Latitude       0
# Longitude      0
# MedHouseVal    0
# dtype: int64

# %% [markdown]
# Afortunadamente, el conjunto de datos no tiene valores faltantes, por lo que podemos ignorar la imputación de datos.

# %%
# Crear la matriz de correlación
correlation_matrix = df.corr()

# Mostrar la matriz de correlación
print(correlation_matrix)
# Out:
#                MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc       1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge    -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms     0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms   -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population   0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup     0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude    -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude   -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# MedHouseVal  0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#              Latitude  Longitude  MedHouseVal
# MedInc      -0.079809  -0.015176     0.688075
# HouseAge     0.011173  -0.108197     0.105623
# AveRooms     0.106389  -0.027540     0.151948
# AveBedrms    0.069721   0.013344    -0.046701
# Population  -0.108785   0.099773    -0.024650
# AveOccup     0.002366   0.002476    -0.023737
# Latitude     1.000000  -0.924664    -0.144160
# Longitude   -0.924664   1.000000    -0.045967
# MedHouseVal -0.144160  -0.045967     1.000000

# %% [markdown]
# En este momento vemos que existen relaciones fuertes entre algunas variables como `MedInc`, `HouseAge`, y `AveRooms`  con `MedHouseVal`, lo cual suena lógico. Podríamos descartar algunas variables que no aportan mucho valor al modelo, pero por simplicidad, las mantendremos todas.

# %% [markdown]
# ## Preprocesamiento de datos
#
# Para el preprocesamiento de datos nos vamos a limitar a la normalización de los datos. La normalización es una técnica común en el aprendizaje automático para mejorar la convergencia y la estabilidad del modelo. En este caso, normalizaremos todas las variables a un rango de 0 a 1.

# %%
dfn = df.drop(
    columns=target_column_name
)  # Eliminar la columna objetivo 'MedHouseVal' del DataFrame y normalizar el resto de columnas
dfn = (dfn - dfn.mean()) / dfn.std()  # Normalizamos las columnas

dfn[target_column_name] = df[
    target_column_name
]  # Añadir la columna objetivo 'MedHouseVal' de nuevo al DataFrame normalizado

dfn.describe()  # Mostramos un resumen de las estadísticas del DataFrame normalizado
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  2.064000e+04  2.064000e+04  2.064000e+04  2.064000e+04  2.064000e+04
# mean   6.058892e-17  6.609700e-17  6.609700e-17 -1.074076e-16 -5.508083e-18
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.774256e+00 -2.196127e+00 -1.852274e+00 -1.610729e+00 -1.256092e+00
# 25%   -6.881019e-01 -8.453727e-01 -3.994399e-01 -1.911670e-01 -5.637952e-01
# 50%   -1.767908e-01  2.864502e-02 -8.078293e-02 -1.010626e-01 -2.291262e-01
# 75%    4.592952e-01  6.642943e-01  2.519554e-01  6.015724e-03  2.644885e-01
# max    5.858144e+00  1.856137e+00  5.516190e+01  6.957003e+01  3.024960e+01
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  2.064000e+04  2.064000e+04  2.064000e+04  20640.000000
# mean   2.409786e-18  2.258314e-15 -8.548545e-15      2.068558
# std    1.000000e+00  1.000000e+00  1.000000e+00      1.153956
# min   -2.289944e-01 -1.447533e+00 -2.385935e+00      0.149990
# 25%   -6.170912e-02 -7.967694e-01 -1.113182e+00      1.196000
# 50%   -2.431526e-02 -6.422715e-01  5.389006e-01      1.797000
# 75%    2.037404e-02  9.729330e-01  7.784775e-01      2.647250
# max    1.194162e+02  2.957996e+00  2.625216e+00      5.000010

# %% [markdown]
# ## Dataset y DataLoader
#
# **Dataset**
#
# En PyTorch, un `Dataset` es una clase que se encarga de cargar y preparar los datos para su posterior uso en el entrenamiento de modelos. Este objeto almacena los datos y proporciona un método para acceder a ellos de manera eficiente y estructurada. Generalmente, `Dataset` se personaliza según el tipo de datos que se maneja, por ejemplo, imágenes, texto o series temporales. Su implementación básica requiere definir los métodos `__len__` para devolver el tamaño del dataset y `__getitem__` para acceder a un elemento específico.
#
# Más información sobre `Dataset` en la documentación oficial de PyTorch: https://pytorch.org/docs/stable/data.html#torch.utils.data.Dataset
#
# **DataLoader**
#
# El `DataLoader` es una clase que se utiliza para envolver un objeto `Dataset` y proporciona un acceso fácil a los datos en lotes durante el entrenamiento, además de otras funcionalidades como el barajado (shuffling) de datos y la carga paralela utilizando múltiples subprocesos. Esto es crucial para el entrenamiento eficiente de modelos, especialmente con grandes volúmenes de datos, ya que gestiona el uso de memoria y mejora el rendimiento computacional.
#
# Más información sobre `DataLoader` en la documentación oficial de PyTorch: https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader
#
# **Objetivo y Uso**
#
# El uso conjunto de `Dataset` y `DataLoader` en PyTorch es fundamental para el flujo de trabajo de entrenamiento de modelos de aprendizaje automático. `Dataset` se encarga de la estructura y accesibilidad de los datos, mientras que `DataLoader` optimiza el proceso de iteración sobre los datos en lotes y facilita operaciones como la mezcla y la carga paralela. Esto permite que el entrenamiento de modelos sea más escalable y eficiente.

# %% [markdown]
# ### Datasets

# %%
class CaliforniaHousingDataset(Dataset):
    def __init__(self, dataframe, target_column):
        self.x = dataframe.drop(columns=target_column).values
        self.y = dataframe[target_column].values

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        x = torch.tensor(self.x[idx], dtype=torch.float32)
        y = torch.tensor([self.y[idx]], dtype=torch.float32)
        return x, y


dataset = CaliforniaHousingDataset(dfn, target_column_name)

# %%
len(dataset)
# Out:
# 20640

# %%
dataset[0]
# Out:
# (tensor([ 2.3447,  0.9821,  0.6285, -0.1538, -0.9744, -0.0496,  1.0525, -1.3278]),
#  tensor([4.5260]))

# %% [markdown]
# Dividimos el conjunto de datos en tres partes: entrenamiento, validación y prueba. La división se realiza de forma aleatoria, utilizando el 80% de los datos para entrenamiento, el 10% para validación y el 10% restante para pruebas.

# %%
total_size = len(dataset)
train_size = int(0.8 * total_size)
val_size = int(0.1 * total_size)
test_size = (
    total_size - train_size - val_size
)  # nos aseguramos de que el tamaño del conjunto de test sea correcto

train_dataset, val_dataset, test_dataset = random_split(
    dataset, [train_size, val_size, test_size]
)

# %%
print(len(train_dataset))
print(len(val_dataset))
print(len(test_dataset))
# Out:
# 16512
# 2064
# 2064

# %% [markdown]
# ### DataLoaders
#
# Definimos los dataloaders para cada conjunto de datos, estos son los que se encargan de cargar los datos en lotes durante el entrenamiento y la evaluación del modelo.

# %%
def get_data_loaders(batch_size, num_workers):

    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers)

    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers)

    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, num_workers=num_workers)
    
    return train_loader, val_loader, test_loader

# %%
train_loader, val_loader, test_loader = get_data_loaders(BATCH_SIZE, NUM_WORKERS) # obtenemos los dataloaders

# probamos un batch del DataLoader
x_batch, y_batch = next(iter(train_loader))
print(x_batch.shape, y_batch.shape)
# Out:
# torch.Size([1024, 8]) torch.Size([1024, 1])

# %%
# pordemos recorrer un barch con un bucle
for x_batch, y_batch in train_loader:
    print(x_batch.shape, y_batch.shape)
# Out:
# torch.Size([1024, 8]) torch.Size([1024, 1])
# torch.Size([1024, 8]) torch.Size([1024, 1])
# torch.Size([1024, 8]) torch.Size([1024, 1])
# torch.Size([1024, 8]) torch.Size([1024, 1])
# torch.Size([1024, 8]) torch.Size([1024, 1])
# torch.Size([1024, 8]) torch.Size([1024, 1])
# torch.Size([1024, 8]) torch.Size([1024, 1])
# torch.Size([1024, 8]) torch.Size([1024, 1])
# torch.Size([1024, 8]) torch.Size([1024, 1])
# torch.Size([1024, 8]) torch.Size([1024, 1])
# torch.Size([1024, 8]) torch.Size([1024, 1])
# torch.Size([1024, 8]) torch.Size([1024, 1])
# torch.Size([1024, 8]) torch.Size([1024, 1])
# torch.Size([1024, 8]) torch.Size([1024, 1])
# torch.Size([1024, 8]) torch.Size([1024, 1])
# torch.Size([1024, 8]) torch.Size([1024, 1])
# torch.Size([128, 8]) torch.Size([128, 1])

# %% [markdown]
# ## Modelo
#
# A continuación, definimos un modelo de regresión lineal simple utilizando PyTorch.

# %%
class MLP(nn.Module):
    def __init__(self, input_size):
        super(MLP, self).__init__()
        self.input = nn.Linear(input_size, 64)
        self.hidden = nn.Linear(64, 32)
        self.output = nn.Linear(32, 1)
        
    def forward(self, x):
        x = F.relu(self.input(x))
        x = F.relu(self.hidden(x))
        x = self.output(x)
        return x


input_len = (
    len(dfn.columns) - 1
)  # Calculamos la cantidad de inputs como la cantidad de columnas -1 (el target)

summary(MLP(input_len), input_size=(BATCH_SIZE, input_len))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# MLP                                      [1024, 1]                 --
# ├─Linear: 1-1                            [1024, 64]                576
# ├─Linear: 1-2                            [1024, 32]                2,080
# ├─Linear: 1-3                            [1024, 1]                 33
# ==========================================================================================
# Total params: 2,689
# Trainable params: 2,689
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 2.75
# ==========================================================================================
# Input size (MB): 0.03
# Forward/backward pass size (MB): 0.79
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.84
# ==========================================================================================

# %% [markdown]
# ## Entrenamiento
#
# Vamos a definir una función de entrenamiento que se encargará de iterar sobre los datos de entrenamiento, calcular las predicciones del modelo, calcular la pérdida y actualizar los pesos del modelo utilizando el optimizador.
#
# Tamibén definimos una función de evaluación que se encargará de calcular la pérdida y otras métricas de evaluación en el conjunto de validación.

# %%
def evaluate(model, criterion, data_loader):
    """
    Evalúa el modelo en los datos proporcionados y calcula la pérdida promedio.

    Args:
        model (torch.nn.Module): El modelo que se va a evaluar.
        criterion (torch.nn.Module): La función de pérdida que se utilizará para calcular la pérdida.
        data_loader (torch.utils.data.DataLoader): DataLoader que proporciona los datos de evaluación.

    Returns:
        float: La pérdida promedio en el conjunto de datos de evaluación.

    """
    model.eval()
    avg_loss = 0
    with torch.no_grad():
        for x, y in data_loader:
            x = x.to(DEVICE)
            y = y.to(DEVICE)
                    
            output = model(x)
            loss = criterion(output, y)        
            avg_loss += loss.item()
        
    avg_loss /= len(data_loader)
    return avg_loss


def train(
    model,
    optimizer,
    criterion,
    train_loader,
    val_loader,
    epochs=10,
    log_fn=None,
    log_every=1,
):
    """
    Entrena el modelo utilizando el optimizador y la función de pérdida proporcionados.

    Args:
        model (torch.nn.Module): El modelo que se va a entrenar.
        optimizer (torch.optim.Optimizer): El optimizador que se utilizará para actualizar los pesos del modelo.
        criterion (torch.nn.Module): La función de pérdida que se utilizará para calcular la pérdida.
        train_loader (torch.utils.data.DataLoader): DataLoader que proporciona los datos de entrenamiento.
        val_loader (torch.utils.data.DataLoader): DataLoader que proporciona los datos de validación.
        epochs (int): Número de épocas de entrenamiento (default: 10).
        log_fn (function): Función que se llamará después de cada log_every épocas con los argumentos (epoch, train_loss, val_loss) (default: None).
        log_every (int): Número de épocas entre cada llamada a log_fn (default: 1).

    Returns:
        Tuple[List[float], List[float]]: Una tupla con dos listas, la primera con el error de entrenamiento de cada época y la segunda con el error de validación de cada época.

    """
    epoch_train_errors = []  # colectamos el error de traing para posterior analisis
    epoch_val_errors = []  # colectamos el error de validacion para posterior analisis

    for epoch in range(epochs):
        model.train()
        epoch_train_loss = 0
        
        for x, y in train_loader:
            x = x.to(DEVICE)
            y = y.to(DEVICE)
            
            optimizer.zero_grad()
            
            output = model(x)
            loss = criterion(output, y)
            loss.backward()
            optimizer.step()
            epoch_train_loss += loss.item()
            
        epoch_train_loss /= len(train_loader)
        epoch_train_errors.append(epoch_train_loss)
        epoch_val_loss = evaluate(model, criterion, val_loader)
        epoch_val_errors.append(epoch_val_loss)
        
        if log_fn is not None:
            if (epoch + 1) % log_every == 0:
                log_fn(epoch, epoch_train_loss, epoch_val_loss)
                
    return epoch_train_errors, epoch_val_errors

# %% [markdown]
# Definimos hiperparámetros como el número de épocas, la tasa de aprendizaje y la función de pérdida.

# %%
# Definimos los hiperparámetros
LR = 0.01
CRITERION = nn.MSELoss().to(DEVICE)
EPOCHS = 100

# %%
def print_log(epoch, train_loss, val_loss):
    print(
        f"Epoch: {epoch + 1:03d}/{EPOCHS:03d} | Train Loss: {train_loss:.5f} | Val Loss: {val_loss:.5f}"
    )

model = MLP(input_len).to(DEVICE)
optimizer = optim.SGD(model.parameters(), lr=LR)

epoch_train_errors, epoch_val_errors = train(
    model, optimizer, CRITERION, train_loader, val_loader, EPOCHS, print_log, 5
)
# Out:
# Epoch: 005/100 | Train Loss: 0.69233 | Val Loss: 0.53438
# Epoch: 010/100 | Train Loss: 0.60648 | Val Loss: 0.48954
# Epoch: 015/100 | Train Loss: 0.55553 | Val Loss: 0.44914
# Epoch: 020/100 | Train Loss: 0.51736 | Val Loss: 0.43009
# Epoch: 025/100 | Train Loss: 0.49149 | Val Loss: 0.41915
# Epoch: 030/100 | Train Loss: 0.46632 | Val Loss: 0.40693
# Epoch: 035/100 | Train Loss: 0.45638 | Val Loss: 0.39788
# Epoch: 040/100 | Train Loss: 0.44331 | Val Loss: 0.39303
# Epoch: 045/100 | Train Loss: 0.43233 | Val Loss: 0.38824
# Epoch: 050/100 | Train Loss: 0.42597 | Val Loss: 0.38776
# Epoch: 055/100 | Train Loss: 0.42173 | Val Loss: 0.38492
# Epoch: 060/100 | Train Loss: 0.42157 | Val Loss: 0.38413
# Epoch: 065/100 | Train Loss: 0.41075 | Val Loss: 0.37966
# Epoch: 070/100 | Train Loss: 0.40639 | Val Loss: 0.38344
# Epoch: 075/100 | Train Loss: 0.40559 | Val Loss: 0.37505
# Epoch: 080/100 | Train Loss: 0.39650 | Val Loss: 0.37517
# Epoch: 085/100 | Train Loss: 0.38948 | Val Loss: 0.37254
# Epoch: 090/100 | Train Loss: 0.39260 | Val Loss: 0.36616
# Epoch: 095/100 | Train Loss: 0.39505 | Val Loss: 0.36701
# Epoch: 100/100 | Train Loss: 0.38515 | Val Loss: 0.36101

# %% [markdown]
# ### Loss durante el entrenamiento
#
# Es importante tener en cuenta que la pérdida es una medida de cuán bien se está desempeñando el modelo en el conjunto de entrenamiento. Sin embargo, la pérdida por sí sola no proporciona una visión completa del rendimiento del modelo. Por lo tanto, es fundamental evaluar el modelo en un conjunto de validación independiente para obtener una idea más precisa de su capacidad para generalizar a datos no vistos.

# %%
def plot_taining(train_errors, val_errors):
    # Graficar los errores
    plt.figure(figsize=(10, 5))  # Define el tamaño de la figura
    plt.plot(train_errors, label="Train Loss")  # Grafica la pérdida de entrenamiento
    plt.plot(val_errors, label="Validation Loss")  # Grafica la pérdida de validación
    plt.title("Training and Validation Loss")  # Título del gráfico
    plt.xlabel("Epochs")  # Etiqueta del eje X
    plt.ylabel("Loss")  # Etiqueta del eje Y
    plt.legend()  # Añade una leyenda
    plt.grid(True)  # Añade una cuadrícula para facilitar la visualización
    plt.show()  # Muestra el gráfico


plot_taining(epoch_train_errors, epoch_val_errors) # graficamos los errores

plot_taining(epoch_train_errors[5:], epoch_val_errors[5:]) # graficamos los errores a partir de la epoca 5 (para ver mejor)

# %% [markdown]
# ## Weight and Bias (W&B)
#
# Weight and Bias es una plataforma que facilita el seguimiento, visualización y colaboración en experimentos de aprendizaje automático. Permite registrar métricas, gráficos y modelos de manera centralizada para facilitar el análisis y la comprensión de los resultados obtenidos durante el entrenamiento de modelos.
#
# **Funcionalidades Principales**
#
# 1. **Seguimiento de Experimentos:** Permite registrar métricas clave como pérdida y precisión a lo largo del entrenamiento para cada experimento.
#
# 2. **Visualización Interactiva:** Proporciona gráficos dinámicos para explorar la evolución de métricas y comparar diferentes experimentos de manera intuitiva.
#
# 3. **Colaboración y Reproducibilidad:** Facilita compartir resultados con colegas y mantener un registro detallado de todos los experimentos realizados.

# %% [markdown]
# > Se requiere una cuenta de W&B, asi como crear un team/equipe y un proyecto para poder utilizar la plataforma. Para más información, visite: https://wandb.ai/site

# %%
import wandb

wandb.login()
# Out:
# wandb: Currently logged in as: josefinalin (RoJo) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %% [markdown]
# ### Sweeps en Weight and Bias
#
# Uno de los aspectos destacados de Weight and Bias son los "sweeps". Estos permiten explorar múltiples combinaciones de hiperparámetros de manera automática, registrando y comparando los resultados de cada configuración. Algunas características de los sweeps incluyen:
#
# - **Automatización de Experimentos:** Ejecución paralela de múltiples configuraciones de hiperparámetros para optimizar el rendimiento del modelo.
#
# - **Análisis de Resultados:** Visualización automática de los resultados de cada configuración para identificar la mejor combinación de hiperparámetros.
#
# - **Ajuste Eficiente:** Permite ajustar rápidamente los hiperparámetros sin necesidad de intervención manual intensiva.
#
# Más información sobre Weight and Bias en la documentación oficial: https://docs.wandb.ai/guides/sweeps

# %%
WANDB_TEAM_NAME = "RoJo"
WANDB_PROJECT = "[WANDB_PROJECT]"

# La configuración del sweep: los parámetros que queremos optimizar
sweep_config = {
    "name": "sweep-california-housing",
    "method": "random",
    "metric": {"name": "val_loss", "goal": "minimize"},
    "parameters": {
        "learning_rate": {"distribution": "uniform", "max": 0.1, "min": 0},
        "optimizer": {"values": ["adam", "sgd"]},
        "batch_size": {"values": [32, 256, 1024, 4096]},
    },
}

# Crea un nuevo sweep (podríamos usar un sweep existente si ya lo hubiéramos creado)
sweep_id = wandb.sweep(sweep_config, project=WANDB_PROJECT)

print(WANDB_TEAM_NAME)
print(WANDB_PROJECT)
# Out:
# Create sweep with ID: p68jzy6o
# Sweep URL: https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o
# RoJo
# [WANDB_PROJECT]

# %% [markdown]
# ### Función Run
#
# La función `run` de W&B se utiliza para iniciar un experimento y registrar métricas clave, hiperparámetros y otros detalles relevantes. Esta función se utiliza para rastrear y visualizar los resultados de los experimentos en la plataforma W&B.

# %%
def wand_log(epoch, train_loss, val_loss):
    wandb.log({"epoch": epoch + 1, "train_loss": train_loss, "val_loss": val_loss})


def sweep_run():
    """
    Función que se ejecutará en cada run del sweep.
    """
    # inicializar un nuevo run
    with wandb.init() as run:
        # leer la configuración del run
        config = wandb.config
        run_learning_rate = config.learning_rate
        run_optimizer = config.optimizer
        run_batch_size = config.batch_size
        
        #Obtener los data loaders
        train_loader, val_loader, _ = get_data_loaders(run_batch_size, NUM_WORKERS)
        
        #Crear el modelo y el optimizador
        model = MLP(input_len).to(DEVICE)
        
        if run_optimizer == "adam":
            optimizer = optim.Adam(model.parameters(), lr=run_learning_rate)
        else:
            optimizer = optim.SGD(model.parameters(), lr=run_learning_rate)
        
        # Entrenamiento y tracking de métricas
        best_val_loss = float('inf')
        for epoch in range(EPOCHS):
            model.train()
            epoch_train_loss = 0
            for x, y in train_loader:
                x = x.to(DEVICE)
                y = y.to(DEVICE)
                
                optimizer.zero_grad()
                output = model(x)
                loss = CRITERION(output, y)
                loss.backward()
                optimizer.step()
                epoch_train_loss += loss.item()
            
            epoch_train_loss /= len(train_loader)
            
            # Evaluación
            val_loss = evaluate(model, CRITERION, val_loader)
            wandb.log({
                "epoch": epoch,
                "train_loss": epoch_train_loss,
                "val_loss": val_loss
            })
            
            # Guardar el mejor modelo
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                torch.save(model.state_dict(), "model.pth")
                wandb.save("model.pth")
        
        # Log del mejor val_loss para que W&B pueda encontrar el mejor run
        wandb.run.summary["val_loss"] = best_val_loss

# %% [markdown]
# ### Corremos el Sweep
#
# Para ejecutar un sweep, creamos un agente que le pide a W&B un conjunto de hiperparámetros para cada experimento. Luego, ejecutamos cada experimento con esos hiperparámetros y registramos los resultados en W&B.
#
# Es importante que podemos ejecutar en varios entornos, incluso al mismo tiempo, para explorar diferentes configuraciones de hiperparámetros y comparar los resultados.

# %%
wandb.agent(sweep_id, function=sweep_run, count=10)
# Out:
# wandb: Agent Starting Run: f0jum4mn with config:
# wandb: 	batch_size: 256
# wandb: 	learning_rate: 0.01793506315111152
# wandb: 	optimizer: adam
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/Users/rodrigobenitez/Documents/GitHub/ORT-AI/Deep Learning/Taller de DL/Clases/Clase 02 - California House Price-20250903/wandb/run-20251022_214707-f0jum4mn</code>
# Syncing run <strong><a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/f0jum4mn' target="_blank">noble-sweep-1</a></strong> to <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o</a>
#  View project at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D</a>
#  View sweep at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o</a>
#  View run at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/f0jum4mn' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/f0jum4mn</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▆▄▆▃▃▃▃▅▃▃▄▄▂▂▂▃▃▂▃▃▂▂▁▂▃▃▁▁▂▁▂▁▂▂▁▁▁▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_loss</td><td>0.235</td></tr><tr><td>val_loss</td><td>0.25085</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">noble-sweep-1</strong> at: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/f0jum4mn' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/f0jum4mn</a><br> View project at: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20251022_214707-f0jum4mn/logs</code>
# wandb: Agent Starting Run: wrs711ze with config:
# wandb: 	batch_size: 4096
# wandb: 	learning_rate: 0.07235253339544061
# wandb: 	optimizer: adam
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/Users/rodrigobenitez/Documents/GitHub/ORT-AI/Deep Learning/Taller de DL/Clases/Clase 02 - California House Price-20250903/wandb/run-20251022_214739-wrs711ze</code>
# Syncing run <strong><a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/wrs711ze' target="_blank">fine-sweep-2</a></strong> to <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o</a>
#  View project at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D</a>
#  View sweep at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o</a>
#  View run at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/wrs711ze' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/wrs711ze</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▆▇▅▅▄▄▃▃▃▄▃▄▃▅▄▃▃▃▄▃▂▂▂▃▃▂▂▂▁▃▂▁▁▁▃▃▂▁▁</td></tr><tr><td>val_loss</td><td>█▆▄▄▃▃▂▃▃▂▃▂▃▃▃▂▂▃▂▂▂▁▁▂▁▂▂▁▂▁▃▁▆▁▁▁▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_loss</td><td>0.2644</td></tr><tr><td>val_loss</td><td>0.3025</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fine-sweep-2</strong> at: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/wrs711ze' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/wrs711ze</a><br> View project at: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20251022_214739-wrs711ze/logs</code>
# wandb: Agent Starting Run: 3s2peqx8 with config:
# wandb: 	batch_size: 1024
# wandb: 	learning_rate: 0.005676628349971059
# wandb: 	optimizer: sgd
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/Users/rodrigobenitez/Documents/GitHub/ORT-AI/Deep Learning/Taller de DL/Clases/Clase 02 - California House Price-20250903/wandb/run-20251022_214755-3s2peqx8</code>
# Syncing run <strong><a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/3s2peqx8' target="_blank">worldly-sweep-3</a></strong> to <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o</a>
#  View project at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D</a>
#  View sweep at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o</a>
#  View run at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/3s2peqx8' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/3s2peqx8</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train_loss</td><td>█▃▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_loss</td><td>0.43225</td></tr><tr><td>val_loss</td><td>0.39599</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">worldly-sweep-3</strong> at: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/3s2peqx8' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/3s2peqx8</a><br> View project at: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20251022_214755-3s2peqx8/logs</code>
# wandb: Agent Starting Run: e4q8je6f with config:
# wandb: 	batch_size: 4096
# wandb: 	learning_rate: 0.023390097282071445
# wandb: 	optimizer: sgd
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/Users/rodrigobenitez/Documents/GitHub/ORT-AI/Deep Learning/Taller de DL/Clases/Clase 02 - California House Price-20250903/wandb/run-20251022_214811-e4q8je6f</code>
# Syncing run <strong><a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/e4q8je6f' target="_blank">treasured-sweep-4</a></strong> to <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o</a>
#  View project at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D</a>
#  View sweep at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o</a>
#  View run at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/e4q8je6f' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/e4q8je6f</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇██</td></tr><tr><td>train_loss</td><td>█▄▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▂▁▂▁▁▂▁▁▁▂▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▄▄▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_loss</td><td>0.43159</td></tr><tr><td>val_loss</td><td>0.43453</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">treasured-sweep-4</strong> at: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/e4q8je6f' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/e4q8je6f</a><br> View project at: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20251022_214811-e4q8je6f/logs</code>
# wandb: Agent Starting Run: 79lm0oqe with config:
# wandb: 	batch_size: 32
# wandb: 	learning_rate: 0.00019839929908672672
# wandb: 	optimizer: adam
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/Users/rodrigobenitez/Documents/GitHub/ORT-AI/Deep Learning/Taller de DL/Clases/Clase 02 - California House Price-20250903/wandb/run-20251022_214827-79lm0oqe</code>
# Syncing run <strong><a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/79lm0oqe' target="_blank">revived-sweep-5</a></strong> to <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o</a>
#  View project at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D</a>
#  View sweep at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o</a>
#  View run at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/79lm0oqe' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/79lm0oqe</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▂▃▃▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▇▇▇▇▇▇▇▇██</td></tr><tr><td>train_loss</td><td>█▆▅▄▄▃▃▃▃▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▆▅▄▄▃▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_loss</td><td>0.26797</td></tr><tr><td>val_loss</td><td>0.28995</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">revived-sweep-5</strong> at: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/79lm0oqe' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/79lm0oqe</a><br> View project at: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20251022_214827-79lm0oqe/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: emiy1556 with config:
# wandb: 	batch_size: 256
# wandb: 	learning_rate: 0.0680949395998928
# wandb: 	optimizer: adam
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/Users/rodrigobenitez/Documents/GitHub/ORT-AI/Deep Learning/Taller de DL/Clases/Clase 02 - California House Price-20250903/wandb/run-20251022_215022-emiy1556</code>
# Syncing run <strong><a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/emiy1556' target="_blank">sunny-sweep-6</a></strong> to <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o</a>
#  View project at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D</a>
#  View sweep at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o</a>
#  View run at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/emiy1556' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/emiy1556</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▆▇▇▇▇▇▇█</td></tr><tr><td>train_loss</td><td>█▃▃▂▂▂▂▁▁▁▂▂▂▁▂▂▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▅█▄▆▅▅▃▃▂▂▃▃▃▂▂▃▂▆▂▂▃▃▄▁▂▃▃▃▂▂▄▁▁▁▃▁▂▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_loss</td><td>0.34501</td></tr><tr><td>val_loss</td><td>0.26033</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">sunny-sweep-6</strong> at: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/emiy1556' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/emiy1556</a><br> View project at: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20251022_215022-emiy1556/logs</code>
# wandb: Agent Starting Run: ga9yvqkv with config:
# wandb: 	batch_size: 32
# wandb: 	learning_rate: 0.0029366772464550217
# wandb: 	optimizer: adam
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/Users/rodrigobenitez/Documents/GitHub/ORT-AI/Deep Learning/Taller de DL/Clases/Clase 02 - California House Price-20250903/wandb/run-20251022_215048-ga9yvqkv</code>
# Syncing run <strong><a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/ga9yvqkv' target="_blank">usual-sweep-7</a></strong> to <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o</a>
#  View project at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D</a>
#  View sweep at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o</a>
#  View run at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/ga9yvqkv' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/ga9yvqkv</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇▇██</td></tr><tr><td>train_loss</td><td>█▆▅▅▅▄▄▄▄▄▃▃▃▃▃▃▃▂▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>█▇▆▅▄▄▄▄▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▂▂▂▁▁▁▃▂▂▁▁▂▁▂▁▂▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_loss</td><td>0.21468</td></tr><tr><td>val_loss</td><td>0.25936</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">usual-sweep-7</strong> at: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/ga9yvqkv' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/ga9yvqkv</a><br> View project at: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20251022_215048-ga9yvqkv/logs</code>
# wandb: Agent Starting Run: uxl36vbq with config:
# wandb: 	batch_size: 32
# wandb: 	learning_rate: 0.06234893216018699
# wandb: 	optimizer: adam
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/Users/rodrigobenitez/Documents/GitHub/ORT-AI/Deep Learning/Taller de DL/Clases/Clase 02 - California House Price-20250903/wandb/run-20251022_215238-uxl36vbq</code>
# Syncing run <strong><a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/uxl36vbq' target="_blank">curious-sweep-8</a></strong> to <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o</a>
#  View project at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D</a>
#  View sweep at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o</a>
#  View run at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/uxl36vbq' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/uxl36vbq</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇▇██</td></tr><tr><td>train_loss</td><td>▃▃▂▁▂▅▅▂▅▅▃▁▅▄▅▄▃▂▃▃▄▂▂▂▁▂▄▃▄▄▃▂▂▄▅▃▅▄█▄</td></tr><tr><td>val_loss</td><td>▁▁▁▃▃▃▁▁▂▂▁▁▃▁▂▃▁▁▂▂▂▁▅▂▁▂▁▁▁▁▁▁▁▂▁▁▁▁▁█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_loss</td><td>1.3389</td></tr><tr><td>val_loss</td><td>0.43118</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">curious-sweep-8</strong> at: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/uxl36vbq' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/uxl36vbq</a><br> View project at: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20251022_215238-uxl36vbq/logs</code>
# wandb: Agent Starting Run: xsdd9g73 with config:
# wandb: 	batch_size: 1024
# wandb: 	learning_rate: 0.05082956083609751
# wandb: 	optimizer: sgd
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/Users/rodrigobenitez/Documents/GitHub/ORT-AI/Deep Learning/Taller de DL/Clases/Clase 02 - California House Price-20250903/wandb/run-20251022_215438-xsdd9g73</code>
# Syncing run <strong><a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/xsdd9g73' target="_blank">solar-sweep-9</a></strong> to <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o</a>
#  View project at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D</a>
#  View sweep at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o</a>
#  View run at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/xsdd9g73' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/xsdd9g73</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▇▇▇▇▇▇████</td></tr><tr><td>train_loss</td><td>█▆▅▄▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▂▂▁▁▁▁▁▁▁▂▁</td></tr><tr><td>val_loss</td><td>█▇▅▄▄▃▃▃▃▂▂▃▂▃▂▃▂▂▃▃▆▂▃▂▂▂▂▂▂▂▂▁▂▂▂▂▁▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_loss</td><td>0.30888</td></tr><tr><td>val_loss</td><td>0.27805</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">solar-sweep-9</strong> at: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/xsdd9g73' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/xsdd9g73</a><br> View project at: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20251022_215438-xsdd9g73/logs</code>
# wandb: Agent Starting Run: 6gaao0hm with config:
# wandb: 	batch_size: 256
# wandb: 	learning_rate: 0.0747898560115426
# wandb: 	optimizer: adam
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/Users/rodrigobenitez/Documents/GitHub/ORT-AI/Deep Learning/Taller de DL/Clases/Clase 02 - California House Price-20250903/wandb/run-20251022_215454-6gaao0hm</code>
# Syncing run <strong><a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/6gaao0hm' target="_blank">brisk-sweep-10</a></strong> to <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o</a>
#  View project at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D</a>
#  View sweep at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/sweeps/p68jzy6o</a>
#  View run at <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/6gaao0hm' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/6gaao0hm</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▁▁▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▆▆▆▆▇▇▇▇▇▇▇▇▇████</td></tr><tr><td>train_loss</td><td>█▆▆▄▆▄▄▄▄▃▃▄▃▂▃▂▂▂▂▂▃▂▁▂▂▁▂▂▂▂▁▁▁▁▂▁▂▂▃▂</td></tr><tr><td>val_loss</td><td>█▄▆▄▅▆▄▄▄▃▃▃▃▆▃▄▂▂▃▃▂▃▂▂▃▁▂▁▁▅▁▂▃▂▂▂▃▃▃▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>99</td></tr><tr><td>train_loss</td><td>0.27647</td></tr><tr><td>val_loss</td><td>0.26391</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">brisk-sweep-10</strong> at: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/6gaao0hm' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D/runs/6gaao0hm</a><br> View project at: <a href='https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D' target="_blank">https://wandb.ai/RoJo/%5BWANDB_PROJECT%5D</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 1 other file(s)
# Find logs at: <code>./wandb/run-20251022_215454-6gaao0hm/logs</code>

# %% [markdown]
# ## Mejor Modelo
#
# Una vez que hemos ejecutado el sweep y registrado los resultados en W&B, podemos identificar el mejor modelo basado en las métricas de evaluación.

# %%
api = wandb.Api()

# nos traemos el sweep (objeto) para analizar los resultados
sweep = api.sweep(f"{WANDB_TEAM_NAME}/{WANDB_PROJECT}/{sweep_id}")

# obtenemos el mejor run
best_run = sweep.best_run()

# imprimimos el mejor run
print(f"Best run {best_run.name} with {best_run.summary['val_loss']}")

# descargamos el modelo del mejor run
best_run.file("model.pth").download(replace=True)
# Out:
# wandb: Sorting runs by +summary_metrics.val_loss
# Best run noble-sweep-1 with 0.25085220734278363
# <_io.TextIOWrapper name='./model.pth' mode='r' encoding='UTF-8'>

# %% [markdown]
# ## Evaluación final
#
# Finalmente, evaluamos el mejor modelo en el conjunto de prueba y visualizamos los resultados obtenidos.

# %%
# restauramos el modelo
model.load_state_dict(torch.load("model.pth"))

# Evaluamos el modelo en el conjunto de test
test_loss = evaluate(model, CRITERION, test_loader)

print(f"Test Loss: {test_loss:.5f}")
# Out:
# Test Loss: 0.21827

# %% [markdown]
# ## Ejercicios
#
#
# 1. **Expansión de la Configuración del Sweep**:
#    - **Objetivo**: Ampliar la configuración del sweep existente para incluir la exploración de nuevas arquitecturas de red neuronal.
#    - **Instrucción**: Expanda el `sweep_config` para incluir parámetros relacionados con la arquitectura del modelo, como el número de capas ocultas (`hidden_layers`) y el número de neuronas por capa (`neurons_per_layer`). Establezca un rango razonable para estos parámetros, por ejemplo, de 1 a 4 para las capas ocultas y de 16 a 128 para las neuronas por capa. Luego, ejecute el sweep y utilice W&B para analizar cómo estos cambios en la arquitectura afectan la métrica de pérdida de validación (`val_loss`).
#
#
# 2. **Experimentación con Funciones de Activación**:
#    - **Objetivo**: Evaluar cómo diferentes funciones de activación afectan el rendimiento del modelo.
#    - **Instrucción**: Añada una nueva variable a la configuración del sweep para probar diferentes funciones de activación (por ejemplo, ReLU, tanh, sigmoid). Modifique el `sweep_config` para incluir un parámetro `activation_function` con valores posibles como ["relu", "tanh", "sigmoid"]. Ejecute el sweep para explorar cuál función de activación resulta en un mejor rendimiento para el modelo y justifique los resultados basándose en las visualizaciones y métricas registradas en W&B.
# ```

# %%
# Sweep config ampliado con exploración de arquitectura y función de activación
sweep_config = {
    "name": "sweep-california-housing-expanded-architecture",
    "method": "random",
    "metric": {"name": "val_loss", "goal": "minimize"},
    "parameters": {
        "learning_rate": {"distribution": "uniform", "min": 0, "max": 0.1},
        "optimizer": {"values": ["adam", "sgd"]},
        "batch_size": {"values": [32, 256, 1024, 4096]},
        "hidden_layers": {"values": [1, 2, 3, 4]},  # Número de capas ocultas
        "neurons_per_layer": {"values": [16, 32, 64, 128]},  # Neuronas por capa
        "activation_function": {"values": ["relu", "tanh", "sigmoid"]}  # Activación
    }
}

# %%
# Definimos el número de características (columnas de entrada)
num_features = len(dfn.columns) - 1  # Restamos 1 por la columna objetivo

# Función para construir el modelo dinámicamente
def build_mlp(input_dim, output_dim, hidden_layers, neurons_per_layer, activation_function):
    import torch.nn as nn

    # Diccionario para seleccionar función de activación con string
    activations = {
        "relu": nn.ReLU(),
        "tanh": nn.Tanh(),
        "sigmoid": nn.Sigmoid()
    }

    layers = []
    last_dim = input_dim
    for _ in range(hidden_layers):
        layers.append(nn.Linear(last_dim, neurons_per_layer))
        layers.append(activations[activation_function])
        last_dim = neurons_per_layer
    layers.append(nn.Linear(last_dim, output_dim))
    model = nn.Sequential(*layers)
    return model

def train_wandb(config=None):
    with wandb.init(config=config):
        config = wandb.config

        # Preparar loaders con el batch_size seleccionado
        train_loader = DataLoader(train_dataset, batch_size=config.batch_size, shuffle=True)
        val_loader = DataLoader(val_dataset, batch_size=config.batch_size)
        
        # Crear el modelo según el sweep
        model = build_mlp(
            input_dim=num_features, 
            output_dim=1,
            hidden_layers=config.hidden_layers, 
            neurons_per_layer=config.neurons_per_layer, 
            activation_function=config.activation_function
        )

        # Elige el optimizador
        if config.optimizer == "adam":
            optimizer = torch.optim.Adam(model.parameters(), lr=config.learning_rate)
        else:
            optimizer = torch.optim.SGD(model.parameters(), lr=config.learning_rate)
        criterion = CRITERION
        
        # Entrenamiento simple
        best_val_loss = float("inf")
        for epoch in range(10):  # O ajusta número de epochs apropiado
            model.train()
            for xb, yb in train_loader:
                optimizer.zero_grad()
                pred = model(xb)
                loss = criterion(pred, yb)
                loss.backward()
                optimizer.step()
            # Evaluación en validación
            model.eval()
            val_loss = 0.0
            count = 0
            with torch.no_grad():
                for xb, yb in val_loader:
                    pred = model(xb)
                    loss = criterion(pred, yb)
                    val_loss += loss.item() * xb.size(0)
                    count += xb.size(0)
            val_loss /= count
            wandb.log({"val_loss": val_loss, "epoch": epoch})
            # Simple early stopping
            if val_loss < best_val_loss:
                best_val_loss = val_loss
        
        # Log de arquitectura usada
        wandb.log({
            "hidden_layers": config.hidden_layers,
            "neurons_per_layer": config.neurons_per_layer,
            "activation_function": config.activation_function,
            "final_val_loss": best_val_loss
        })

# %%
# Inicializa el sweep y ejecuta algunos experimentos automáticamente
sweep_id = wandb.sweep(sweep_config, project="california-housing")
# Ejemplo: lanzar 10 corridas del sweep (ajusta a tus recursos)
wandb.agent(sweep_id, train_wandb, count=10)
# Out:
# Create sweep with ID: h43lzkzh
# Sweep URL: https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh
# wandb: Agent Starting Run: i6rv9fsn with config:
# wandb: 	activation_function: sigmoid
# wandb: 	batch_size: 256
# wandb: 	hidden_layers: 1
# wandb: 	learning_rate: 0.014681237272622384
# wandb: 	neurons_per_layer: 16
# wandb: 	optimizer: adam
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/Users/rodrigobenitez/Documents/GitHub/ORT-AI/Deep Learning/Taller de DL/Clases/Clase 02 - California House Price-20250903/wandb/run-20251022_225301-i6rv9fsn</code>
# Syncing run <strong><a href='https://wandb.ai/RoJo/california-housing/runs/i6rv9fsn' target="_blank">fresh-sweep-1</a></strong> to <a href='https://wandb.ai/RoJo/california-housing' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh' target="_blank">https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh</a>
#  View project at <a href='https://wandb.ai/RoJo/california-housing' target="_blank">https://wandb.ai/RoJo/california-housing</a>
#  View sweep at <a href='https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh' target="_blank">https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh</a>
#  View run at <a href='https://wandb.ai/RoJo/california-housing/runs/i6rv9fsn' target="_blank">https://wandb.ai/RoJo/california-housing/runs/i6rv9fsn</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>final_val_loss</td><td>▁</td></tr><tr><td>hidden_layers</td><td>▁</td></tr><tr><td>neurons_per_layer</td><td>▁</td></tr><tr><td>val_loss</td><td>█▄▃▂▂▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>activation_function</td><td>sigmoid</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>final_val_loss</td><td>0.39645</td></tr><tr><td>hidden_layers</td><td>1</td></tr><tr><td>neurons_per_layer</td><td>16</td></tr><tr><td>val_loss</td><td>0.39673</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">fresh-sweep-1</strong> at: <a href='https://wandb.ai/RoJo/california-housing/runs/i6rv9fsn' target="_blank">https://wandb.ai/RoJo/california-housing/runs/i6rv9fsn</a><br> View project at: <a href='https://wandb.ai/RoJo/california-housing' target="_blank">https://wandb.ai/RoJo/california-housing</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251022_225301-i6rv9fsn/logs</code>
# wandb: Agent Starting Run: f5v67x8u with config:
# wandb: 	activation_function: relu
# wandb: 	batch_size: 256
# wandb: 	hidden_layers: 3
# wandb: 	learning_rate: 0.022746803951025775
# wandb: 	neurons_per_layer: 64
# wandb: 	optimizer: adam
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/Users/rodrigobenitez/Documents/GitHub/ORT-AI/Deep Learning/Taller de DL/Clases/Clase 02 - California House Price-20250903/wandb/run-20251022_225306-f5v67x8u</code>
# Syncing run <strong><a href='https://wandb.ai/RoJo/california-housing/runs/f5v67x8u' target="_blank">solar-sweep-2</a></strong> to <a href='https://wandb.ai/RoJo/california-housing' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh' target="_blank">https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh</a>
#  View project at <a href='https://wandb.ai/RoJo/california-housing' target="_blank">https://wandb.ai/RoJo/california-housing</a>
#  View sweep at <a href='https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh' target="_blank">https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh</a>
#  View run at <a href='https://wandb.ai/RoJo/california-housing/runs/f5v67x8u' target="_blank">https://wandb.ai/RoJo/california-housing/runs/f5v67x8u</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>final_val_loss</td><td>▁</td></tr><tr><td>hidden_layers</td><td>▁</td></tr><tr><td>neurons_per_layer</td><td>▁</td></tr><tr><td>val_loss</td><td>██▅▃▄▃▂▁▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>activation_function</td><td>relu</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>final_val_loss</td><td>0.31721</td></tr><tr><td>hidden_layers</td><td>3</td></tr><tr><td>neurons_per_layer</td><td>64</td></tr><tr><td>val_loss</td><td>0.32087</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">solar-sweep-2</strong> at: <a href='https://wandb.ai/RoJo/california-housing/runs/f5v67x8u' target="_blank">https://wandb.ai/RoJo/california-housing/runs/f5v67x8u</a><br> View project at: <a href='https://wandb.ai/RoJo/california-housing' target="_blank">https://wandb.ai/RoJo/california-housing</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251022_225306-f5v67x8u/logs</code>
# wandb: Agent Starting Run: hij6mx4v with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 1024
# wandb: 	hidden_layers: 3
# wandb: 	learning_rate: 0.044581942811530974
# wandb: 	neurons_per_layer: 32
# wandb: 	optimizer: sgd
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/Users/rodrigobenitez/Documents/GitHub/ORT-AI/Deep Learning/Taller de DL/Clases/Clase 02 - California House Price-20250903/wandb/run-20251022_225312-hij6mx4v</code>
# Syncing run <strong><a href='https://wandb.ai/RoJo/california-housing/runs/hij6mx4v' target="_blank">usual-sweep-3</a></strong> to <a href='https://wandb.ai/RoJo/california-housing' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh' target="_blank">https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh</a>
#  View project at <a href='https://wandb.ai/RoJo/california-housing' target="_blank">https://wandb.ai/RoJo/california-housing</a>
#  View sweep at <a href='https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh' target="_blank">https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh</a>
#  View run at <a href='https://wandb.ai/RoJo/california-housing/runs/hij6mx4v' target="_blank">https://wandb.ai/RoJo/california-housing/runs/hij6mx4v</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>final_val_loss</td><td>▁</td></tr><tr><td>hidden_layers</td><td>▁</td></tr><tr><td>neurons_per_layer</td><td>▁</td></tr><tr><td>val_loss</td><td>█▄▃▂▂▂▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>activation_function</td><td>tanh</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>final_val_loss</td><td>0.48038</td></tr><tr><td>hidden_layers</td><td>3</td></tr><tr><td>neurons_per_layer</td><td>32</td></tr><tr><td>val_loss</td><td>0.48038</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">usual-sweep-3</strong> at: <a href='https://wandb.ai/RoJo/california-housing/runs/hij6mx4v' target="_blank">https://wandb.ai/RoJo/california-housing/runs/hij6mx4v</a><br> View project at: <a href='https://wandb.ai/RoJo/california-housing' target="_blank">https://wandb.ai/RoJo/california-housing</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251022_225312-hij6mx4v/logs</code>
# wandb: Agent Starting Run: moe6el8v with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 4096
# wandb: 	hidden_layers: 1
# wandb: 	learning_rate: 0.02380783713239435
# wandb: 	neurons_per_layer: 128
# wandb: 	optimizer: sgd
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/Users/rodrigobenitez/Documents/GitHub/ORT-AI/Deep Learning/Taller de DL/Clases/Clase 02 - California House Price-20250903/wandb/run-20251022_225317-moe6el8v</code>
# Syncing run <strong><a href='https://wandb.ai/RoJo/california-housing/runs/moe6el8v' target="_blank">vague-sweep-4</a></strong> to <a href='https://wandb.ai/RoJo/california-housing' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh' target="_blank">https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh</a>
#  View project at <a href='https://wandb.ai/RoJo/california-housing' target="_blank">https://wandb.ai/RoJo/california-housing</a>
#  View sweep at <a href='https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh' target="_blank">https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh</a>
#  View run at <a href='https://wandb.ai/RoJo/california-housing/runs/moe6el8v' target="_blank">https://wandb.ai/RoJo/california-housing/runs/moe6el8v</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>final_val_loss</td><td>▁</td></tr><tr><td>hidden_layers</td><td>▁</td></tr><tr><td>neurons_per_layer</td><td>▁</td></tr><tr><td>val_loss</td><td>█▃▂▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>activation_function</td><td>tanh</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>final_val_loss</td><td>0.57212</td></tr><tr><td>hidden_layers</td><td>1</td></tr><tr><td>neurons_per_layer</td><td>128</td></tr><tr><td>val_loss</td><td>0.57212</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">vague-sweep-4</strong> at: <a href='https://wandb.ai/RoJo/california-housing/runs/moe6el8v' target="_blank">https://wandb.ai/RoJo/california-housing/runs/moe6el8v</a><br> View project at: <a href='https://wandb.ai/RoJo/california-housing' target="_blank">https://wandb.ai/RoJo/california-housing</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251022_225317-moe6el8v/logs</code>
# wandb: Agent Starting Run: 33hrp3zh with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 32
# wandb: 	hidden_layers: 2
# wandb: 	learning_rate: 0.06576453119413998
# wandb: 	neurons_per_layer: 64
# wandb: 	optimizer: sgd
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/Users/rodrigobenitez/Documents/GitHub/ORT-AI/Deep Learning/Taller de DL/Clases/Clase 02 - California House Price-20250903/wandb/run-20251022_225323-33hrp3zh</code>
# Syncing run <strong><a href='https://wandb.ai/RoJo/california-housing/runs/33hrp3zh' target="_blank">blooming-sweep-5</a></strong> to <a href='https://wandb.ai/RoJo/california-housing' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh' target="_blank">https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh</a>
#  View project at <a href='https://wandb.ai/RoJo/california-housing' target="_blank">https://wandb.ai/RoJo/california-housing</a>
#  View sweep at <a href='https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh' target="_blank">https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh</a>
#  View run at <a href='https://wandb.ai/RoJo/california-housing/runs/33hrp3zh' target="_blank">https://wandb.ai/RoJo/california-housing/runs/33hrp3zh</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>final_val_loss</td><td>▁</td></tr><tr><td>hidden_layers</td><td>▁</td></tr><tr><td>neurons_per_layer</td><td>▁</td></tr><tr><td>val_loss</td><td>█▅▅▃▃▂▂▁▁▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>activation_function</td><td>tanh</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>final_val_loss</td><td>0.34101</td></tr><tr><td>hidden_layers</td><td>2</td></tr><tr><td>neurons_per_layer</td><td>64</td></tr><tr><td>val_loss</td><td>0.37613</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">blooming-sweep-5</strong> at: <a href='https://wandb.ai/RoJo/california-housing/runs/33hrp3zh' target="_blank">https://wandb.ai/RoJo/california-housing/runs/33hrp3zh</a><br> View project at: <a href='https://wandb.ai/RoJo/california-housing' target="_blank">https://wandb.ai/RoJo/california-housing</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251022_225323-33hrp3zh/logs</code>
# wandb: Agent Starting Run: 9cqb9xfe with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 32
# wandb: 	hidden_layers: 3
# wandb: 	learning_rate: 0.02254091474709231
# wandb: 	neurons_per_layer: 64
# wandb: 	optimizer: sgd
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/Users/rodrigobenitez/Documents/GitHub/ORT-AI/Deep Learning/Taller de DL/Clases/Clase 02 - California House Price-20250903/wandb/run-20251022_225328-9cqb9xfe</code>
# Syncing run <strong><a href='https://wandb.ai/RoJo/california-housing/runs/9cqb9xfe' target="_blank">pretty-sweep-6</a></strong> to <a href='https://wandb.ai/RoJo/california-housing' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh' target="_blank">https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh</a>
#  View project at <a href='https://wandb.ai/RoJo/california-housing' target="_blank">https://wandb.ai/RoJo/california-housing</a>
#  View sweep at <a href='https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh' target="_blank">https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh</a>
#  View run at <a href='https://wandb.ai/RoJo/california-housing/runs/9cqb9xfe' target="_blank">https://wandb.ai/RoJo/california-housing/runs/9cqb9xfe</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>final_val_loss</td><td>▁</td></tr><tr><td>hidden_layers</td><td>▁</td></tr><tr><td>neurons_per_layer</td><td>▁</td></tr><tr><td>val_loss</td><td>█▆▄▅▇▄▃▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>activation_function</td><td>tanh</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>final_val_loss</td><td>0.3661</td></tr><tr><td>hidden_layers</td><td>3</td></tr><tr><td>neurons_per_layer</td><td>64</td></tr><tr><td>val_loss</td><td>0.3661</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">pretty-sweep-6</strong> at: <a href='https://wandb.ai/RoJo/california-housing/runs/9cqb9xfe' target="_blank">https://wandb.ai/RoJo/california-housing/runs/9cqb9xfe</a><br> View project at: <a href='https://wandb.ai/RoJo/california-housing' target="_blank">https://wandb.ai/RoJo/california-housing</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251022_225328-9cqb9xfe/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 27lmg0dx with config:
# wandb: 	activation_function: relu
# wandb: 	batch_size: 4096
# wandb: 	hidden_layers: 1
# wandb: 	learning_rate: 0.091043421495371
# wandb: 	neurons_per_layer: 16
# wandb: 	optimizer: adam
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/Users/rodrigobenitez/Documents/GitHub/ORT-AI/Deep Learning/Taller de DL/Clases/Clase 02 - California House Price-20250903/wandb/run-20251022_225343-27lmg0dx</code>
# Syncing run <strong><a href='https://wandb.ai/RoJo/california-housing/runs/27lmg0dx' target="_blank">bright-sweep-7</a></strong> to <a href='https://wandb.ai/RoJo/california-housing' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh' target="_blank">https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh</a>
#  View project at <a href='https://wandb.ai/RoJo/california-housing' target="_blank">https://wandb.ai/RoJo/california-housing</a>
#  View sweep at <a href='https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh' target="_blank">https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh</a>
#  View run at <a href='https://wandb.ai/RoJo/california-housing/runs/27lmg0dx' target="_blank">https://wandb.ai/RoJo/california-housing/runs/27lmg0dx</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>final_val_loss</td><td>▁</td></tr><tr><td>hidden_layers</td><td>▁</td></tr><tr><td>neurons_per_layer</td><td>▁</td></tr><tr><td>val_loss</td><td>█▆▄▄▃▂▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>activation_function</td><td>relu</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>final_val_loss</td><td>0.42444</td></tr><tr><td>hidden_layers</td><td>1</td></tr><tr><td>neurons_per_layer</td><td>16</td></tr><tr><td>val_loss</td><td>0.43294</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">bright-sweep-7</strong> at: <a href='https://wandb.ai/RoJo/california-housing/runs/27lmg0dx' target="_blank">https://wandb.ai/RoJo/california-housing/runs/27lmg0dx</a><br> View project at: <a href='https://wandb.ai/RoJo/california-housing' target="_blank">https://wandb.ai/RoJo/california-housing</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251022_225343-27lmg0dx/logs</code>
# wandb: Agent Starting Run: 83snagae with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 32
# wandb: 	hidden_layers: 3
# wandb: 	learning_rate: 0.06150055691533744
# wandb: 	neurons_per_layer: 16
# wandb: 	optimizer: adam
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/Users/rodrigobenitez/Documents/GitHub/ORT-AI/Deep Learning/Taller de DL/Clases/Clase 02 - California House Price-20250903/wandb/run-20251022_225349-83snagae</code>
# Syncing run <strong><a href='https://wandb.ai/RoJo/california-housing/runs/83snagae' target="_blank">crisp-sweep-8</a></strong> to <a href='https://wandb.ai/RoJo/california-housing' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh' target="_blank">https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh</a>
#  View project at <a href='https://wandb.ai/RoJo/california-housing' target="_blank">https://wandb.ai/RoJo/california-housing</a>
#  View sweep at <a href='https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh' target="_blank">https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh</a>
#  View run at <a href='https://wandb.ai/RoJo/california-housing/runs/83snagae' target="_blank">https://wandb.ai/RoJo/california-housing/runs/83snagae</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>final_val_loss</td><td>▁</td></tr><tr><td>hidden_layers</td><td>▁</td></tr><tr><td>neurons_per_layer</td><td>▁</td></tr><tr><td>val_loss</td><td>▅▁▂▅▅█▄▄▅▅</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>activation_function</td><td>tanh</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>final_val_loss</td><td>0.4373</td></tr><tr><td>hidden_layers</td><td>3</td></tr><tr><td>neurons_per_layer</td><td>16</td></tr><tr><td>val_loss</td><td>0.48663</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">crisp-sweep-8</strong> at: <a href='https://wandb.ai/RoJo/california-housing/runs/83snagae' target="_blank">https://wandb.ai/RoJo/california-housing/runs/83snagae</a><br> View project at: <a href='https://wandb.ai/RoJo/california-housing' target="_blank">https://wandb.ai/RoJo/california-housing</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251022_225349-83snagae/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: qia5a4a0 with config:
# wandb: 	activation_function: tanh
# wandb: 	batch_size: 32
# wandb: 	hidden_layers: 2
# wandb: 	learning_rate: 0.06323931960162298
# wandb: 	neurons_per_layer: 32
# wandb: 	optimizer: sgd
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/Users/rodrigobenitez/Documents/GitHub/ORT-AI/Deep Learning/Taller de DL/Clases/Clase 02 - California House Price-20250903/wandb/run-20251022_225404-qia5a4a0</code>
# Syncing run <strong><a href='https://wandb.ai/RoJo/california-housing/runs/qia5a4a0' target="_blank">jolly-sweep-9</a></strong> to <a href='https://wandb.ai/RoJo/california-housing' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh' target="_blank">https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh</a>
#  View project at <a href='https://wandb.ai/RoJo/california-housing' target="_blank">https://wandb.ai/RoJo/california-housing</a>
#  View sweep at <a href='https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh' target="_blank">https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh</a>
#  View run at <a href='https://wandb.ai/RoJo/california-housing/runs/qia5a4a0' target="_blank">https://wandb.ai/RoJo/california-housing/runs/qia5a4a0</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>final_val_loss</td><td>▁</td></tr><tr><td>hidden_layers</td><td>▁</td></tr><tr><td>neurons_per_layer</td><td>▁</td></tr><tr><td>val_loss</td><td>█▅▄▃▃▁▂▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>activation_function</td><td>tanh</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>final_val_loss</td><td>0.36673</td></tr><tr><td>hidden_layers</td><td>2</td></tr><tr><td>neurons_per_layer</td><td>32</td></tr><tr><td>val_loss</td><td>0.36673</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">jolly-sweep-9</strong> at: <a href='https://wandb.ai/RoJo/california-housing/runs/qia5a4a0' target="_blank">https://wandb.ai/RoJo/california-housing/runs/qia5a4a0</a><br> View project at: <a href='https://wandb.ai/RoJo/california-housing' target="_blank">https://wandb.ai/RoJo/california-housing</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251022_225404-qia5a4a0/logs</code>
# wandb: Agent Starting Run: gwpp46t4 with config:
# wandb: 	activation_function: relu
# wandb: 	batch_size: 1024
# wandb: 	hidden_layers: 3
# wandb: 	learning_rate: 0.0403119913009408
# wandb: 	neurons_per_layer: 32
# wandb: 	optimizer: adam
# creating run (0.0s)
# Tracking run with wandb version 0.21.3
# Run data is saved locally in <code>/Users/rodrigobenitez/Documents/GitHub/ORT-AI/Deep Learning/Taller de DL/Clases/Clase 02 - California House Price-20250903/wandb/run-20251022_225410-gwpp46t4</code>
# Syncing run <strong><a href='https://wandb.ai/RoJo/california-housing/runs/gwpp46t4' target="_blank">ethereal-sweep-10</a></strong> to <a href='https://wandb.ai/RoJo/california-housing' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>Sweep page: <a href='https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh' target="_blank">https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh</a>
#  View project at <a href='https://wandb.ai/RoJo/california-housing' target="_blank">https://wandb.ai/RoJo/california-housing</a>
#  View sweep at <a href='https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh' target="_blank">https://wandb.ai/RoJo/california-housing/sweeps/h43lzkzh</a>
#  View run at <a href='https://wandb.ai/RoJo/california-housing/runs/gwpp46t4' target="_blank">https://wandb.ai/RoJo/california-housing/runs/gwpp46t4</a>
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>final_val_loss</td><td>▁</td></tr><tr><td>hidden_layers</td><td>▁</td></tr><tr><td>neurons_per_layer</td><td>▁</td></tr><tr><td>val_loss</td><td>█▄▃▂▂▂▄▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>activation_function</td><td>relu</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>final_val_loss</td><td>0.33774</td></tr><tr><td>hidden_layers</td><td>3</td></tr><tr><td>neurons_per_layer</td><td>32</td></tr><tr><td>val_loss</td><td>0.33774</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">ethereal-sweep-10</strong> at: <a href='https://wandb.ai/RoJo/california-housing/runs/gwpp46t4' target="_blank">https://wandb.ai/RoJo/california-housing/runs/gwpp46t4</a><br> View project at: <a href='https://wandb.ai/RoJo/california-housing' target="_blank">https://wandb.ai/RoJo/california-housing</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20251022_225410-gwpp46t4/logs</code>

# %% [markdown]
# Los resultados obtenidos en W&B mostraron que, en casos donde se usó SGD como optimizador, la loss fue mayor en comparación a los resultados obtenidos cuando se usó Adam como optimizador en el entrenamiento. Puede tener que ver con que Adam es capaz de adaptar el learning rate según cada parámetro, haciendo que converga más rápido y que performe mejor.
#
# Por otra parte, tamaño de batch de 1024 parece proporcionar un buen equilibrio entre la eficiencia computacional y la capacidad de generalización del modelo.
#
# La gráfica también muestra que las configuraciones con Adam tienden a converger más rápidamente y de manera más estable, como se puede observar en las curvas más suaves y con menor variabilidad en la pérdida de validación a lo largo del entrenamiento. (Adjunto print en entrega con gráficos)
