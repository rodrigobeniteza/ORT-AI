# %% [markdown]
# # Imports

# %%
from tqdm import tqdm
import joblib

import matplotlib.pyplot as plt
import numpy as np

import pandas as pd

from skimage import data, color, feature
from skimage.transform import resize, rescale

from utils import (
    non_max_suppression,
    sliding_window,
    detections_by_scale,
    evaluate_detections_by_scale,
    global_multiscale_detection,
    evaluate_detections_at_scale
)

# %% [markdown]
# # Clasificador

# %%
import os

os.getcwd()
# Out:
# '/Users/rodrigobenitez/Documents/GitHub/ORT-AI/ML para AI/Obligatorio/Detector'

# %%
# Cargar modelo entrenado
clf = joblib.load('../models/rf_optimized.joblib')

# Cargar standard scaler
scaler = joblib.load('../models/scaler_rf.joblib')

# Cargar pca
pca = joblib.load('../models/pca_rf.joblib')

# Tamaño de las imagenes de entrenamiento
size = (64,64)

# %% [markdown]
# # Imagen de prueba

# %%
# Imagen de prueba
# test_image = data.astronaut()
test_image = plt.imread('../Imgs_Prueba/1_Rostro.jpg')
test_image = color.rgb2gray(test_image)
test_image = (test_image*255).astype(np.uint8)
# test_image = rescale(test_image, 0.5)
# test_image = test_image[:160, 40:180]
test_image = rescale(test_image, 0.8)

# %%
test_image.shape
# Out:
# (762, 1144)

# %%
# Visualizamos la imagen
# Buscamos la escala de los rostros
fig, ax = plt.subplots()
ax.imshow(test_image, cmap='gray')

true_scale = 2.5
Ni, Nj = (int(true_scale * s) for s in size)

ax.add_patch(plt.Rectangle((38, 32), Nj, Ni, edgecolor='red', alpha=1, lw=1, facecolor='none'))
plt.show()

# %% [markdown]
# # Desempeño según umbrales

# %%
# scaler = joblib.load('../models/scaler.joblib')

# %%
detecciones = evaluate_detections_at_scale(
    image=test_image,
    clf=clf,
    scaler=scaler,
    pca=pca,
    scale=true_scale,
    thresholds=[0.5, 0.1, 0.8],
    patch_size=(64, 64),
    overlapThresh=0.1,
    plot=True
)

# %% [markdown]
# ### Desempeño en varias escalas según umbral

# %%
test_scales = np.linspace(0.125, 0.9, 20)

raw_detections, detections = evaluate_detections_by_scale(
    test_image,
    test_scales,
    clf=clf,
    scaler=scaler,
    pca=pca,
    thresholds=[0.5, 0.1, 0.8],
    patch_size=(64, 64),
    step=2,
    true_scale=true_scale,
    number_faces=1
)
# Out:
# 100%|██████████| 20/20 [00:32<00:00,  1.63s/it]

# %% [markdown]
# # Detección global

# %%
filtered_indices, filtered_sizes = global_multiscale_detection(
    test_image,
    clf=clf,
    scaler=scaler,
    pca=pca,
    test_scales=np.linspace(0.125, 0.9, 20),
    patch_size=(64, 64),
    threshold=0.1,
    step=2,
    overlapThresh=0.3,
    plot=True
)
# Out:
# Escalas: 100%|██████████| 20/20 [00:30<00:00,  1.53s/it]
